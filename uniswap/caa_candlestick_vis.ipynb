# %%
import pandas as pd
import finplot as fplt

# %%
# Read the data from a CSV file
#df = pd.read_pickle(f'./uni_WETH_USDT_2022.pkl')
#df = pd.read_pickle(f'./uni_WBTC_USDT_2022.pkl')
df = pd.read_pickle(f'./uni_UNI_USDC_2022.pkl')

# Create a candlestick chart
fplt.candlestick_ochl(df[['open','close','high','low']])
fplt.show()
